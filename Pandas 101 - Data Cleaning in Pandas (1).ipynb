# %% [markdown]
# # Data Cleaning in Pandas

# %% [markdown]
# ##### Import Package

# %%
import pandas as pd

# %% [markdown]
# ##### Import Data

# %%
df = pd.read_excel("C:\\Users\\HP\\Desktop\\New folder\\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# ##### Data Dimension

# %%
df.shape
# Out:
# (21, 8)

# %% [markdown]
# ##### Delete not useful column

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# ##### Replace All  Strange Symbol  In Last name

# %%
df["Last_Name"] = df["Last_Name"].str.strip("-/ ,:;.-_123456789")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %% [markdown]
# ##### Formating Phone Number Column

# %%
df['Phone_Number']=df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')

df['Phone_Number']=df['Phone_Number'].apply(lambda x: str(x))

df['Phone_Number']=df['Phone_Number'].apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[6:])

df['Phone_Number'].replace('nan--',np.nan,inplace=True)

df['Phone_Number'].replace('Na--',np.nan,inplace=True)

df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2              NaN
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6              NaN
# 7     876-678-3469
# 8              NaN
# 9     123-545-5421
# 10             NaN
# 11             NaN
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17             NaN
# 18             NaN
# 19    876-678-3469
# 20    876-678-3469
# Name: Phone_Number, dtype: object

# %% [markdown]
# ##### Separating Address Column

# %%
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',',2, expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White           NaN
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter           NaN
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %% [markdown]
# ##### Replacing data in paying customer

# %%
df['Paying Customer']=df['Paying Customer'].replace('Y','Yes')

df['Paying Customer']=df['Paying Customer'].replace('N','No')

df['Paying Customer']=df['Paying Customer'].replace('N/a',np.nan)

df['Paying Customer'].value_counts()
# Out:
# Yes    14
# No      6
# Name: Paying Customer, dtype: int64

# %% [markdown]
# ##### Replacing data in Do Not Contact

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].replace('N','No')

df['Do_Not_Contact']=df['Do_Not_Contact'].replace('Y','Yes')

df['Do_Not_Contact']
# Out:
# 0      No
# 1     Yes
# 2     NaN
# 3     Yes
# 4      No
# 5     Yes
# 6      No
# 7      No
# 8     NaN
# 9      No
# 10     No
# 11    NaN
# 12     No
# 13     No
# 14     No
# 15     No
# 16     No
# 17    NaN
# 18    Yes
# 19     No
# 20     No
# Name: Do_Not_Contact, dtype: object

# %% [markdown]
# ##### Fill NAN Field

# %%
df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# First_Name         0
# Last_Name          0
# Phone_Number       0
# Address            0
# Paying Customer    0
# Do_Not_Contact     0
# Street_Address     0
# State              0
# Zip_Code           0
# dtype: int64

# %% [markdown]
# ##### Remove all customer that don't contact

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Yes':
        df.drop(x, inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876-678-3469
# 20        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %% [markdown]
# ##### Remove All Customer That They Without  Phone Number

# %%
df['Phone_Number'].replace('',np.nan,inplace=True)

df.dropna(subset=['Phone_Number'],inplace=True)

df['Phone_Number'].isnull().value_counts()        


#another way 


#for x in df.index:
#    if df.loc[x, "Phone_Number"] == '':
#        df.drop(x, inplace=True)
# Out:
# False    11
# Name: Phone_Number, dtype: int64

# %% [markdown]
# ##### Remove Duplicates Rows

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes             No
# 4                 123 Dragons Road             Yes             No
# 7                    98 Clue Drive              No             No
# 9       25th Main Street, New York             Yes             No
# ...

# %% [markdown]
# ##### Reset Index

# %%
df = df.reset_index(drop=True)
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0        1001      Frodo     Baggins  123-545-5421
# 1        1005        Jon        Snow  876-678-3469
# 2        1008   Sherlock      Holmes  876-678-3469
# 3        1010      Peter      Parker  123-545-5421
# 4        1013        Don      Draper  123-543-2345
# 5        1014     Leslie       Knope  876-678-3469
# 6        1015       Toby  Flenderson  304-762-2467
# 7        1016        Ron     Weasley  123-545-5421
# 8        1017   Michael        Scott  123-643-9775
# 9        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire             Yes             No
# 1                123 Dragons Road             Yes             No
# 2                   98 Clue Drive              No             No
# 3      25th Main Street, New York             Yes             No
# 4                2039 Main Street             Yes             No
# ...
