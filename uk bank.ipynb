# %% [markdown]
# ## EXPLORATORY DATA  ANALYSIS

# %% [markdown]
# ### UK BANK CUSTOMER

# %% [markdown]
# #### IMPORTING LIBRARIES

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
from matplotlib import pyplot  
import datetime

# %% [markdown]
# #### IMPORTING DATASET

# %%
df=pd.read_excel('C:\\Users\\HP\\Desktop\\New folder\\archive\\UK Bank Customers.xlsx')
df
# Out:
#       Customer ID       Name   Surname  Gender  Age          Province  \
# 0       100000001      Simon     Walsh    Male   21           England
# 1       400000002    Jasmine    Miller  Female   34  Northern Ireland
# 2       100000003       Liam     Brown    Male   46           England
# 3       300000004     Trevor      Parr    Male   32             Wales
# 4       100000005    Deirdre   Pullman  Female   38           England
# ...           ...        ...       ...     ...  ...               ...
# 4009    200004010        Sam     Lewis    Male   64          Scotland
# 4010    200004011      Keith    Hughes    Male   52          Scotland
# 4011    200004012     Hannah  Springer  Female   50          Scotland
# 4012    200004013  Christian      Reid    Male   51          Scotland
# 4013    300004014    Stephen       May    Male   33             Wales
#
#      Job Classification Date Joined    Balance
# 0          White Collar   05.Jan.15  113810.15
# ...

# %% [markdown]
# #### EDIT DISPLAY OPTION

# %%
pd.set_option('display.max.rows',4015)
pd.set_option('display.max.columns',9)
df
# Out:
#       Customer ID         Name     Surname  Gender  Age          Province  \
# 0       100000001        Simon       Walsh    Male   21           England
# 1       400000002      Jasmine      Miller  Female   34  Northern Ireland
# 2       100000003         Liam       Brown    Male   46           England
# 3       300000004       Trevor        Parr    Male   32             Wales
# 4       100000005      Deirdre     Pullman  Female   38           England
# 5       300000006          Ava     Coleman  Female   30             Wales
# 6       100000007      Dorothy     Thomson  Female   34           England
# 7       200000008         Lisa        Knox  Female   48          Scotland
# 8       300000009         Ruth    Campbell  Female   33             Wales
# 9       100000010      Dominic        Parr    Male   42           England
# 10      100000011      Dominic       Lewis    Male   40           England
# 11      100000012     Benjamin       Grant    Male   39           England
# ...

# %% [markdown]
# #### EXPLORING & ANALYSING DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 9 columns):
# Customer ID           4014 non-null int64
# Name                  4014 non-null object
# Surname               4014 non-null object
# Gender                4014 non-null object
# Age                   4014 non-null int64
# Province              4014 non-null object
# Job Classification    4014 non-null object
# Date Joined           4014 non-null object
# Balance               4014 non-null float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 282.4+ KB

# %%
df.describe().round(2)
# Out:
#         Customer ID      Age    Balance
# count  4.014000e+03  4014.00    4014.00
# mean   1.696831e+08    38.61   39766.45
# std    8.865374e+07     9.82   29859.49
# min    1.000000e+08    15.00      11.52
# 25%    1.000020e+08    31.00   16115.37
# 50%    1.000038e+08    37.00   33567.33
# 75%    2.000031e+08    45.00   57533.93
# max    4.000038e+08    64.00  183467.70

# %%
df['Province'].unique()
# Out:
# array(['England', 'Northern Ireland', 'Wales', 'Scotland'], dtype=object)

# %%
df['Province'].value_counts()
# Out:
# England             2159
# Scotland            1124
# Wales                520
# Northern Ireland     211
# Name: Province, dtype: int64

# %%
df.isnull().sum()
# Out:
# Customer ID           0
# Name                  0
# Surname               0
# Gender                0
# Age                   0
# Province              0
# Job Classification    0
# Date Joined           0
# Balance               0
# month                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#       Customer ID      Name   Surname  Gender  Age  Province  \
# 3977    100003978     Scott    Gibson    Male   35   England
# 698     200000699     Jason   Cameron    Male   60  Scotland
# 3032    200003033     Gavin     Blake    Male   45  Scotland
# 2398    200002399     Wendy  Ferguson  Female   57  Scotland
# 1489    300001490   Richard   Wallace    Male   43     Wales
# 344     100000345  Benjamin      Ince    Male   36   England
# 3573    100003574  Kimberly     Blake  Female   40   England
# 3772    200003773    Trevor    Tucker    Male   43  Scotland
# 1685    100001686    Edward    Watson    Male   36   England
# 1253    300001254    Lauren     Lyman  Female   36     Wales
#
#      Job Classification Date Joined   Balance      month
# 3977       White Collar  2015-12-28  18055.90   December
# 698               Other  2015-05-27  49081.50        May
# 3032        Blue Collar  2015-11-05  88366.08   November
# 2398              Other  2015-09-30   4025.97  September
# ...

# %% [markdown]
# ##### COUNT ING OF GENDER

# %%
df1=df[['Customer ID','Gender']].groupby(by='Gender',as_index=True).count()
df1=df1.reset_index()
plt.pyplot.bar(df1['Gender'].unique().tolist(),df1['Customer ID'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ##### ANOTHER WAY

# %%
df['Gender'].value_counts().plot.bar()

# %% [markdown]
# ##### count customer per job

# %%
#count customer per job
df2=df[['Customer ID','Job Classification']].groupby(by='Job Classification',as_index=True).count()
#df2.reset_index(inplace=True)
plt.pyplot.pie(df2['Customer ID'] ,labels=df2.index,colors=['#4CAF99','cyan','blue'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19c14d16088>,
# ...
#  [Text(0.7496313665274983, 0.8050172757886104, 'Blue Collar'),
#   Text(-0.8348509301187227, 0.7162568844205993, 'Other'),
#   Text(0.044755707027766364, -1.0990891350060945, 'White Collar')],
#  [Text(0.4088898362877263, 0.4391003322483329, '26.1%'),
#   Text(-0.45537323461021234, 0.39068557332032683, '25.2%'),
#   Text(0.024412203833327106, -0.5995031645487787, '48.7%')])

# %% [markdown]
# ##### MAX OF BALANCE  & MIN OF BALANCE

# %%
print('Max of Balance'+':'+str(df['Balance'].min()),'Max of Balance'+':' +str(df['Balance'].max()))
# Out:
# Max of Balance:11.52 Max of Balance:183467.7

# %% [markdown]
# ##### EXTRACT DAY OF WEEK

# %%
df['Date Joined']=pd.to_datetime(df['Date Joined'])
df['Day of week']=df['Date Joined'].dt.day_name()

# %% [markdown]
# ##### EXTRACT MONTH

# %%
df['Date Joined']=pd.to_datetime(df['Date Joined'])
df['month']=df['Date Joined'].dt.month_name()
df
# Out:
#       Customer ID       Name   Surname  Gender  Age          Province  \
# 0       100000001      Simon     Walsh    Male   21           England
# 1       400000002    Jasmine    Miller  Female   34  Northern Ireland
# 2       100000003       Liam     Brown    Male   46           England
# 3       300000004     Trevor      Parr    Male   32             Wales
# 4       100000005    Deirdre   Pullman  Female   38           England
# ...           ...        ...       ...     ...  ...               ...
# 4009    200004010        Sam     Lewis    Male   64          Scotland
# 4010    200004011      Keith    Hughes    Male   52          Scotland
# 4011    200004012     Hannah  Springer  Female   50          Scotland
# 4012    200004013  Christian      Reid    Male   51          Scotland
# 4013    300004014    Stephen       May    Male   33             Wales
#
#      Job Classification Date Joined    Balance     month Day of week
# ...

# %% [markdown]
# ##### SUM BALANCE PER DAY

# %%
df2=df[['Balance','Day of week']].groupby(by='Day of week').sum()
df2.reset_index(inplace=True)
plt.pyplot.plot(df2['Day of week'],df2['Balance'])
plt.pyplot.show()

# %% [markdown]
# ##### SUM BALANCE PER MONTH

# %%
plt.pyplot.figure (figsize= (12,5)) 
df3=df[['month','Balance']].groupby(by='month').sum()
df3.reset_index(inplace=True)
plt.pyplot.plot(df3['month'],df3['Balance'])
plt.pyplot.show()

# %% [markdown]
# ##### SAVE DATAFRAME

# %%
df.to_csv('C:\\Users\\HP\\Desktop\\UK BANAK.csv')
